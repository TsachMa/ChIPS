# %%
import os
import sys
import re
import datetime
import time
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import os
import subprocess

import numpy as np
import pandas as pd
import sys

#added informational comment to test github

# %%
#defining cutoffenergy and kpoing spacing arrays 
cutoff_energies = [600]

kpoint_spacings = [0.04]

pressures = [0, 4, 8]

elements = ["La", "Ru", "Bi"]

#confirm choices
print("Cutoff energies: ", cutoff_energies)
print("Kpoint Spacings: ", kpoint_spacings)
print("Pressures: ", pressures)
print("Elements: ", elements)

storage_directory = "/home/gridsan/tmackey/Records/KISS_LaRuBi" 
print("Storage directory: ", storage_directory)

#cell_file_directory = "/home/gridsan/tmackey/Data/KISS_cell_files_First_Test_1_File" - 1 file
#cell_file_directory = "/home/gridsan/tmackey/Data/KISS_cell_files_First_Test_10etc" - 100 files
#cell_file_directory = "/home/gridsan/tmackey/Data/KISS_cell_files_First_Test_10_files" #- 10 files
cell_file_directory = "/home/gridsan/tmackey/Data/KISS_cell_files_First_Test" #- all files
print("Cell file directory: ", cell_file_directory)

#in the 10 file test, the compounds concerneded are :
#K3 In Se3 - not supposed to produce
#Nd5 (Mo3 O16) - not supposed to produce
#K3 (C O3) - not supposed to produce
#Cs In Cl3 - not supposed to produce
#Cs Cu Bi - not supposed to produce
#Ba (Si2 O5) - not supposed to produce
#Cu Br Se - not supposed to produce 
#Ce Cu5 Sn - not supposed to produce
#K6 Ge2 Te6 - not supposed to produce
#Os3 (C O)12 - not supposed to produce
#La In S - manually copied in, supposed to produce

CASTEP_tools_directory = "/home/gridsan/tmackey/MyTools/CASTEP_Scripts"
print("CASTEP tools directory: ", CASTEP_tools_directory)

all_steps_script = "/home/gridsan/tmackey/MyTools/CASTEP_Scripts/all_steps.sh"
print("All steps script: ", all_steps_script)

all_ternary_compounds_directory = "/home/gridsan/tmackey/Data/all_ternary_compounds.csv"
print("All ternary compounds directory: ", all_ternary_compounds_directory)
# Out:
# Cutoff energies:  [600]
# Kpoint Spacings:  [0.04]
# Pressures:  [0, 4, 8]
# Elements:  ['La', 'Ru', 'Bi']
# Storage directory:  /home/gridsan/tmackey/Records/KISS_LaRuBi
# Cell file directory:  /home/gridsan/tmackey/Data/KISS_cell_files_First_Test
# CASTEP tools directory:  /home/gridsan/tmackey/MyTools/CASTEP_Scripts
# All steps script:  /home/gridsan/tmackey/MyTools/CASTEP_Scripts/all_steps.sh
# All ternary compounds directory:  /home/gridsan/tmackey/Data/all_ternary_compounds.csv

# %%
# remove any old data from the storage directory

def remove_directory(directory_path):
    # Kill processes that are accessing .nfs files in the directory
    # try:
    #     result = subprocess.run(["lsof | grep .nfs | awk '{print $2}' | xargs kill -9"], shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    #     if result.returncode != 0:
    #         print(f"Failed to kill processes accessing .nfs files in {directory_path}: {result.stderr.decode('utf-8')}")
    # except Exception as e:
    #     print(f"Failed to kill processes accessing .nfs files in {directory_path}: {str(e)}")

    # Remove the directory
    try:
        result = subprocess.run(["rm", "-rf", directory_path], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        if result.returncode == 0:
            print(f"Successfully removed {directory_path}")
        else:
            print(f"Failed to remove {directory_path}: {result.stderr.decode('utf-8')}")
    except Exception as e:
        print(f"Failed to remove {directory_path}: {str(e)}")

remove_directory(storage_directory)
# Out:
# Successfully removed /home/gridsan/tmackey/Records/KISS_LaRuBi

# %%
#initialize the data with all_steps
#create new directory within the storage directory corresponding to that particular condition / parameter

def generate_command(all_steps_script, storage_directory, cutoff_energy, kpoint_spacing, pressure, cell_file_directory, all_ternary_compounds_directory, runtype, elements):

    command = [all_steps_script, "-d", storage_directory, "-e", str(cutoff_energy), "-k", str(kpoint_spacing), "-p", str(pressure), "-c", cell_file_directory, "-t", all_ternary_compounds_directory, "-r", runtype] + elements
    
    try:
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        if result.returncode == 0:
            print(f"Command executed successfully:\n{result.stdout.decode('utf-8')}")
        else:
            print(f"Failed to execute command: {result.stderr.decode('utf-8')}")
    except Exception as e:
        print(f"Failed to execute command: {str(e)}")

#initialization step 
for pressure in pressures:
    generate_command(all_steps_script,storage_directory, cutoff_energies[0], kpoint_spacings[0], pressure, cell_file_directory, all_ternary_compounds_directory, "init", elements)
#what should happen:
#1. the new directory within the storage directory should be created
# Out:
# Command executed successfully:
# starting reading_inputs
# finished reading_inputs
# start defining functions
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-0/
# Running initialization instructions
#
# Command executed successfully:
# starting reading_inputs
# finished reading_inputs
# start defining functions
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-4/
# Running initialization instructions
#
# Command executed successfully:
# starting reading_inputs
# finished reading_inputs
# start defining functions
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-8/
# Running initialization instructions

# %%
#import the decoration and initailization script and confirm your output directory
import decoration_and_initialization as deco

for pressure in pressures:
    output_dir = storage_directory + "/" + elements[0] + elements[1] + elements[2] + "-" + str(cutoff_energies[0]) + "-" + str(kpoint_spacings[0]) + "-" + str(pressure) 
    #test
    print(output_dir)
    # "/home/gridsan/tmackey/MyTools/CASTEP_Scripts/TestFolder/SuperCloudTest1/outputfiles/LaPbBi-600-0.04-0"
# Out:
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-0
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-4
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-8

# %%
#update the deco package with importlib
import importlib
importlib.reload(deco)

for pressure in pressures:
    output_dir = storage_directory + "/" + elements[0] + elements[1] + elements[2] + "-" + str(cutoff_energies[0]) + "-" + str(kpoint_spacings[0]) + "-" + str(pressure) 
    #test
    print(output_dir)
    deco.edit_all_cell_files(cell_file_directory, pressure, kpoint_spacings[0], elements, all_ternary_compounds_directory, output_dir)

#what should happen:
#1. 2 synthetic cell files should be created from the cell file in the input directory and copied to the output directory
#they should have the correct pressure, kpoint spacing and element substitutions made. their cutoff energies should be set to whatever the cutoff_energy is provided as 
#Pressure - checked
#Kpoints - checked

#for the folder of incomplete files (100etc) it correctly identified and labeled the cell files
# Out:
# /home/gridsan/tmackey/Records/KISS_LaRuBi/LaRuBi-600-0.04-0
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/2249_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3Error: code not found in all_ternaries.csv
#
#
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
#
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/160978_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/2914_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/151118_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/56442_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/159242_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/73805_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/97581_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
#
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/100696_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/201426_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3Error: code not found in all_ternaries.csv
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/197519_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/164734_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/255022_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/629491_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/83956_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/26577_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/160981_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/11210_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/96187_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/66642_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/50189_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/1231_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
#
#
#
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvElements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/68081_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
#
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/82848_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
#
#
# Error: code not found in all_ternaries.csv
# Elements array for filename /home/gridsan/tmackey/Data/KISS_cell_files_First_Test/2024_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete_incomplete.cell is not length 3
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
#
#
#
#
#
# Error: code not found in all_ternaries.csvError: code not found in all_ternaries.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 9
#       7     #test
#       8     print(output_dir)
# ----> 9     deco.edit_all_cell_files(cell_file_directory, pressure, kpoint_spacings[0], elements, all_ternary_compounds_directory, output_dir)
#      11 #what should happen:
#      12 #1. 2 synthetic cell files should be created from the cell file in the input directory and copied to the output directory
#      13 #they should have the correct pressure, kpoint spacing and element substitutions made. their cutoff energies should be set to whatever the cutoff_energy is provided as
#    (...)
#      16
#      17 #for the folder of incomplete files (100etc) it correctly identified and labeled the cell files
#
# File ~/MyTools/CASTEP_Scripts/decoration_and_initialization.py:788, in edit_all_cell_files(folder_name, pressure, kpoint_spacing, elements_to_swap_in, all_ternaries_file_name, output_directory)
#     784 #print("List of arguments:", list_of_arguments)
#     785 # Create a multiprocessing Pool
#     786 with multiprocessing.Pool(num_cores) as pool:
#     787     # Use the Pool's map function to apply the process_file function to every file name
# --> 788     pool.map(process_file_wrapper, list_of_arguments)
#
# File /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File /state/partition1/llgrid/pkg/anaconda/anaconda3-2023a/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
#take in something like "Synth_20381_LaLaInBiSPb.cell" and return "20381"
def get_code_from_file_name(file_name):
    return file_name.split("_")[1]

codes = [get_code_from_file_name(file_name) for file_name in os.listdir(output_dir)]

#remove duplicates
codes = list(set(codes))

print(codes)
# Out:
# ['8494', '54570', '55511', '410419', '424333', '101016', '106529', '142736', '83378', '62893', '154791', '55495', '168470', '154741', '183028', '65000', '420766', '101011', '431662', '174471', '150777', '250752', '189116', '7781', '80005', '54733', '168458', '244020', '163719', '410732', '423170', '183347', '370040', '20350', '12736', '13930', '411077', '157336', '106417', '412576', '67988', '11406', '150404', '173171', '12049', '63511', '67985', '12738', '192462', '83907', '192802', '156950', '55668', '230729', '185105', '190838', '412577', '99240', '419491', '182050', '5620']

# %%
import importlib
importlib.reload(deco)

deco.init_csv("checkpoint.csv", output_dir)

for code in codes:
    deco.write_csv("checkpoint.csv", all_ternary_compounds_directory, code, os.path.join(cell_file_directory, code + ".cell"), output_dir, elements)

#this should produce an output in the test folder that looks like this for test folder 1 and the 10 file test folder 
# code,structure type,permutation,completion,error,error_type
# 20381,In5Nd4S13,"{'La': 'La', 'In': 'Pb', 'S': 'Bi'}",yes,,
# 20381,In5Nd4S13,"{'La': 'La', 'In': 'Bi', 'S': 'Pb'}",yes,,
# Out:
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv
# Error: code not found in all_ternaries.csv

# %%
generate_command(all_steps_script,storage_directory, cutoff_energies[0], kpoint_spacings[0], pressures[0], cell_file_directory, all_ternary_compounds_directory, "first_step_only", elements)

#tested with the 10 file folder 
#tested the different components by commenting out the unwanted stuff
#when focusing on the .param file it produced .param files that 
#(a) all lines unmodified except for the very end 
#(b) a line specifying the cutoff energy at the very end

#when tested on the .param file and the .sbatch file 
#(a) the .param file was modified as above
#(b) the sbatch file was modified correctly to make it runnable on supercloud 
#EXAMPLE: 
# #!/bin/bash
# #SBATCH -N 1
# #SBATCH -n 4
# #SBATCH --array=1
# #SBATCH --mem=4500
# #SBATCH --time=04:00:00
# #SBATCH --output="output/Synth_20381_LaLaInPbSBi_output.txt"
# #SBATCH --error="error/Synth_20381_LaLaInPbSBi_error.txt"

# echo "Date              = $(date)"
# echo "Hostname          = $(hostname -s)"
# echo "Working Directory = $(pwd)"

# module add mpi/openmpi-4.1.3

# export PATH=/home/gridsan/tmackey/support/CASTEP-21.11/bin/linux_x86_64_gfortran--mpi:$PATH

# export PATH=/home/gridsan/tmackey/support/CASTEP-21.11/bin/linux_x86_64_gfortran--serial:$PATH

# mpirun -np 4 castep.mpi Synth_20381_LaLaInPbSBi

#uncommented the sbatch submission line in all_steps and everthing looks like it's running smoothly!

##### TESTING WITH ALL CELL FILES (>300 decorated cell files)
# Out:
# Command executed successfully:
# starting reading_inputs
# finished reading_inputs
# start defining functions
# /home/gridsan/tmackey/MyTools/CASTEP_Scripts/TestFolder/SuperCloudTest1/outputfiles/LaRuBi-600-0.04-0/
# Running first step only instructions
# Running generate_params.py
# ['Synth_54570_GdLaSnBiCoRu.cell', 'Synth_370040_TbLaInBiCoRu.cell', 'output', 'Synth_410419_PtRuYbLaSnBi.cell', 'Synth_67985_PrLaIBiFeRu.cell', 'Synth_12738_PtRuLaLaSnBi.cell', 'Synth_156950_AuRuGdLaSbBi.cell', 'Synth_174471_ErLaSbBiPdRu.cell', 'Synth_83378_CeLaSbBiPdRu.cell', 'Synth_431662_HoLaInBiRhRu.cell', 'Synth_101011_CeLaSnBiCuRu.cell', 'Synth_7781_ErLaSnBiNiRu.cell', 'Synth_150777_PtRuCeLaSnBi.cell', 'Synth_423170_IrRuLaLaSbBi.cell', 'Synth_412576_PtRuDyLaInBi.cell', 'Synth_182050_EuLaSnBiCuRu.cell', 'Synth_173171_YbLaSbBiCdRu.cell', 'Synth_154741_ErLaTeBiCuRu.cell', 'Synth_192462_ErLaSnBiCuRu.cell', 'Synth_13930_LaLaSbBiPdRu.cell', 'Synth_189116_CeLaSnBiPdRu.cell', 'Synth_168470_AuRuErLaTeBi.cell', 'Synth_411077_PrLaInBiNiRu.cell', 'Synth_192802_BiBiTbLaFeRu.cell', 'Synth_8494_PrLaSbBiPdRu.cell', 'Synth_419491_AuRuPrLaSnBi.cell', 'Synth_55495_CeLaSnBiNiRu.cell', 'Synth_101016_LaLaInBiNiRu.cell', 'Synth_150404_PrLaSbBiNiRu.cell', 'Synth_185105_LaLaInBiNiRu.cell', 'Synth_157336_GdLaSbBiCoRu.cell', 'Synth_11406_LaLaIBiRuRu.cell', 'Synth_183028_TmLaSnBiCuRu.cell', 'Synth_65000_CeLaInBiNiRu.cell', 'Synth_190838_CeLaSnBiPdRu.cell', 'Synth_20350_CeLaSnBiNiRu.cell', 'Synth_67988_GdLaIBiMnRu.cell', 'Synth_80005_CeLaSbBiPdRu.cell', 'Synth_5620_GdLaInBiNiRu.cell', 'Synth_412577_PtRuTbLaInBi.cell', 'Synth_62893_PrLaInBiNiRu.cell', 'Synth_420766_YbLaSnBiNiRu.cell', 'Synth_54733_CeLaInBiPdRu.cell', 'Synth_168458_PrLaSbBiFeRu.cell', 'error', 'checkpoint.csv', 'Synth_163719_AuRuCeLaSbBi.cell', 'Synth_55668_NdLaSnBiMnRu.cell', 'Synth_424333_LaLaSnBiRhRu.cell', 'Synth_230729_CeLaSnBiRhRu.cell', 'Synth_183347_LaLaInBiPdRu.cell', 'Synth_12736_PtRuSmLaSnBi.cell', 'Synth_250752_LaLaSnBiZnRu.cell', 'Synth_63511_HoLaSnBiCoRu.cell', 'Synth_12049_BiBiHoLaPdRu.cell', 'Synth_99240_CeLaInBiPdRu.cell', 'Synth_83907_LaLaSbBiCrRu.cell', 'Synth_142736_AuRuCeLaSnBi.cell', 'Synth_244020_AuRuDyLaSbBi.cell', 'Synth_410732_LaLaSnBiRhRu.cell', 'Synth_154791_ErLaTeBiAgRu.cell', 'Synth_55511_SmLaSnBiCoRu.cell', 'Synth_106529_SmLaSnBiCuRu.cell', 'Synth_106417_CeLaSnBiNiRu.cell']
# starting_loop
# Synth_54570_GdLaSnBiCoRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_370040_TbLaInBiCoRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_410419_PtRuYbLaSnBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_67985_PrLaIBiFeRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_12738_PtRuLaLaSnBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_156950_AuRuGdLaSbBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_174471_ErLaSbBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_83378_CeLaSbBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_431662_HoLaInBiRhRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_101011_CeLaSnBiCuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_7781_ErLaSnBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_150777_PtRuCeLaSnBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_423170_IrRuLaLaSbBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_412576_PtRuDyLaInBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_182050_EuLaSnBiCuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_173171_YbLaSbBiCdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_154741_ErLaTeBiCuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_192462_ErLaSnBiCuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_13930_LaLaSbBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_189116_CeLaSnBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_168470_AuRuErLaTeBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_411077_PrLaInBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_192802_BiBiTbLaFeRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_8494_PrLaSbBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_419491_AuRuPrLaSnBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_55495_CeLaSnBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_101016_LaLaInBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_150404_PrLaSbBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_185105_LaLaInBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_157336_GdLaSbBiCoRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_11406_LaLaIBiRuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_183028_TmLaSnBiCuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_65000_CeLaInBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_190838_CeLaSnBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_20350_CeLaSnBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_67988_GdLaIBiMnRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_80005_CeLaSbBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_5620_GdLaInBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_412577_PtRuTbLaInBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_62893_PrLaInBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_420766_YbLaSnBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_54733_CeLaInBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_168458_PrLaSbBiFeRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_163719_AuRuCeLaSbBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_55668_NdLaSnBiMnRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_424333_LaLaSnBiRhRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_230729_CeLaSnBiRhRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_183347_LaLaInBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_12736_PtRuSmLaSnBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_250752_LaLaSnBiZnRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_63511_HoLaSnBiCoRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_12049_BiBiHoLaPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_99240_CeLaInBiPdRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_83907_LaLaSbBiCrRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_142736_AuRuCeLaSnBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_244020_AuRuDyLaSbBi.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_410732_LaLaSnBiRhRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_154791_ErLaTeBiAgRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_55511_SmLaSnBiCoRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_106529_SmLaSnBiCuRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Synth_106417_CeLaSnBiNiRu.cell
# task                 : geometryoptimization
#
# xc_functional        : LDA
#
# spin_polarized       : false
#
# fix_occupancy        : false
#
# metals_method        : dm
#
# mixing_scheme        : pulay
#
# max_scf_cycles       : 300
#
# opt_strategy         : speed
#
# page_wvfns           : 0
#
# num_dump_cycles      : 0
#
# backup_interval      : 39600
#
# geom_method          : BFGS
#
# geom_max_iter        : 100
#
# mix_history_length   : 100
#
# finite_basis_corr    : auto
#
# fixed_npw            : false
#
# write_cell_structure : true
#
# write_bib            : false
#
# write_otfg           : false
#
# write_cst_esp        : false
#
# write_bands          : false
#
# write_geom           : false
#
# bs_write_eigenvalues : false
#
# PERC_EXTRA_BANDS     : 60.0
#
# calculate_stress     : true
#
# write_checkpoint : BACKUP=MINIMAL
#
# Running generate_sbatch.py

# %%
#GO TO TERMINAL AND MANUALLY PUSH THE JOB ARRAY(S) TO QUEUE USING SBATCH 
#######
#######
#######
#######

# %%
import collect

import importlib
importlib.reload(collect)

collect.main(output_dir)

#tested on the 10-file folder
#this should update the checkpoint file and create a log file that updates the round column everytime its called

#after 1st push, checkpoint file looks good:
# code,structure type,permutation,completion,error,error_type
# 20381,In5Nd4S13,"{'La': 'La', 'In': 'Pb', 'S': 'Bi'}",incomplete,False,N/A
# 20381,In5Nd4S13,"{'La': 'La', 'In': 'Bi', 'S': 'Pb'}",incomplete,False,N/A

#log file also looks good:
# name,n-bands round,n-bands error,suggested extra bands
# Synth_20381_LaLaInPbSBi.cell,0,0,0
# Synth_20381_LaLaInBiSPb.cell,0,0,0

#after 2nd push, checkpoint file looks the same and log file is appropriately updated 
# Synth_20381_LaLaInPbSBi.cell,0,0,0
# Synth_20381_LaLaInBiSPb.cell,0,0,0
# Synth_20381_LaLaInPbSBi.cell,1,0,0
# Synth_20381_LaLaInBiSPb.cell,1,0,0
# Out:
# False
# ['Synth_54570_GdLaSnBiCoRu.cell', 'Synth_370040_TbLaInBiCoRu.cell', 'Synth_410419_PtRuYbLaSnBi.cell', 'Synth_67985_PrLaIBiFeRu.cell', 'Synth_12049_BiBiHoLaPdRu-out.cell', 'Synth_12738_PtRuLaLaSnBi.cell', 'Synth_156950_AuRuGdLaSbBi.cell', 'Synth_174471_ErLaSbBiPdRu.cell', 'Synth_83378_CeLaSbBiPdRu.cell', 'Synth_431662_HoLaInBiRhRu.cell', 'Synth_101011_CeLaSnBiCuRu.cell', 'Synth_7781_ErLaSnBiNiRu.cell', 'Synth_150777_PtRuCeLaSnBi.cell', 'Synth_423170_IrRuLaLaSbBi.cell', 'Synth_412576_PtRuDyLaInBi.cell', 'Synth_182050_EuLaSnBiCuRu.cell', 'Synth_173171_YbLaSbBiCdRu.cell', 'Synth_154741_ErLaTeBiCuRu.cell', 'Synth_192462_ErLaSnBiCuRu.cell', 'Synth_13930_LaLaSbBiPdRu.cell', 'Synth_189116_CeLaSnBiPdRu.cell', 'Synth_168470_AuRuErLaTeBi.cell', 'Synth_411077_PrLaInBiNiRu.cell', 'Synth_192802_BiBiTbLaFeRu.cell', 'Synth_8494_PrLaSbBiPdRu.cell', 'Synth_419491_AuRuPrLaSnBi.cell', 'Synth_55495_CeLaSnBiNiRu.cell', 'Synth_101016_LaLaInBiNiRu.cell', 'Synth_150404_PrLaSbBiNiRu.cell', 'Synth_185105_LaLaInBiNiRu.cell', 'Synth_157336_GdLaSbBiCoRu.cell', 'Synth_11406_LaLaIBiRuRu.cell', 'Synth_183028_TmLaSnBiCuRu.cell', 'Synth_65000_CeLaInBiNiRu.cell', 'Synth_190838_CeLaSnBiPdRu.cell', 'Synth_20350_CeLaSnBiNiRu.cell', 'Synth_67988_GdLaIBiMnRu.cell', 'Synth_80005_CeLaSbBiPdRu.cell', 'Synth_5620_GdLaInBiNiRu.cell', 'Synth_412577_PtRuTbLaInBi.cell', 'Synth_62893_PrLaInBiNiRu.cell', 'Synth_420766_YbLaSnBiNiRu.cell', 'Synth_54733_CeLaInBiPdRu.cell', 'Synth_168458_PrLaSbBiFeRu.cell', 'Synth_163719_AuRuCeLaSbBi.cell', 'Synth_55668_NdLaSnBiMnRu.cell', 'Synth_424333_LaLaSnBiRhRu.cell', 'Synth_230729_CeLaSnBiRhRu.cell', 'Synth_183347_LaLaInBiPdRu.cell', 'Synth_12736_PtRuSmLaSnBi.cell', 'Synth_250752_LaLaSnBiZnRu.cell', 'Synth_63511_HoLaSnBiCoRu.cell', 'Synth_12049_BiBiHoLaPdRu.cell', 'Synth_99240_CeLaInBiPdRu.cell', 'Synth_83907_LaLaSbBiCrRu.cell', 'Synth_142736_AuRuCeLaSnBi.cell', 'Synth_244020_AuRuDyLaSbBi.cell', 'Synth_410732_LaLaSnBiRhRu.cell', 'Synth_154791_ErLaTeBiAgRu.cell', 'Synth_55511_SmLaSnBiCoRu.cell', 'Synth_106529_SmLaSnBiCuRu.cell', 'Synth_106417_CeLaSnBiNiRu.cell']
# {'name': 'Synth_54570_GdLaSnBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_370040_TbLaInBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_410419_PtRuYbLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_67985_PrLaIBiFeRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_12049_BiBiHoLaPdRu-out.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_12738_PtRuLaLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_156950_AuRuGdLaSbBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_174471_ErLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_83378_CeLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_431662_HoLaInBiRhRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_101011_CeLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_7781_ErLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_150777_PtRuCeLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_423170_IrRuLaLaSbBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_412576_PtRuDyLaInBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_182050_EuLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_173171_YbLaSbBiCdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_154741_ErLaTeBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_192462_ErLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_13930_LaLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_189116_CeLaSnBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_168470_AuRuErLaTeBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_411077_PrLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_192802_BiBiTbLaFeRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_8494_PrLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_419491_AuRuPrLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_55495_CeLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_101016_LaLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_150404_PrLaSbBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_185105_LaLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_157336_GdLaSbBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_11406_LaLaIBiRuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_183028_TmLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_65000_CeLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_190838_CeLaSnBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_20350_CeLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_67988_GdLaIBiMnRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_80005_CeLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_5620_GdLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_412577_PtRuTbLaInBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_62893_PrLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_420766_YbLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_54733_CeLaInBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_168458_PrLaSbBiFeRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_163719_AuRuCeLaSbBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_55668_NdLaSnBiMnRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_424333_LaLaSnBiRhRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_230729_CeLaSnBiRhRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_183347_LaLaInBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_12736_PtRuSmLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_250752_LaLaSnBiZnRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_63511_HoLaSnBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_12049_BiBiHoLaPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_99240_CeLaInBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_83907_LaLaSbBiCrRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}
# {'name': 'Synth_142736_AuRuCeLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_244020_AuRuDyLaSbBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_410732_LaLaSnBiRhRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_154791_ErLaTeBiAgRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_55511_SmLaSnBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_106529_SmLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# {'name': 'Synth_106417_CeLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}
# [{'name': 'Synth_54570_GdLaSnBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_370040_TbLaInBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_410419_PtRuYbLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_67985_PrLaIBiFeRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}, {'name': 'Synth_12049_BiBiHoLaPdRu-out.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}, {'name': 'Synth_12738_PtRuLaLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_156950_AuRuGdLaSbBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_174471_ErLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_83378_CeLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}, {'name': 'Synth_431662_HoLaInBiRhRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_101011_CeLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_7781_ErLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}, {'name': 'Synth_150777_PtRuCeLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_423170_IrRuLaLaSbBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_412576_PtRuDyLaInBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_182050_EuLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_173171_YbLaSbBiCdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_154741_ErLaTeBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_192462_ErLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_13930_LaLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_189116_CeLaSnBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_168470_AuRuErLaTeBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_411077_PrLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_192802_BiBiTbLaFeRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_8494_PrLaSbBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}, {'name': 'Synth_419491_AuRuPrLaSnBi.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_55495_CeLaSnBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_101016_LaLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_150404_PrLaSbBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_185105_LaLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_157336_GdLaSbBiCoRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_11406_LaLaIBiRuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_183028_TmLaSnBiCuRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_65000_CeLaInBiNiRu.cell', 'n-bands round': 0, 'n-bands error': 'N/A', 'suggested extra bands': 'N/A'}, {'name': 'Synth_190838_CeLaSnBiPdRu.cell', 'n-bands round': 0, 'n-bands error': 0, 'suggested extra bands': 0}, {'name': 'Synth_20350_CeLaSnBiNiRu.cell',  ...
# ['Synth_54570_GdLaSnBiCoRu.cell', 'Synth_370040_TbLaInBiCoRu.cell', 'Synth_410419_PtRuYbLaSnBi.cell', 'Synth_67985_PrLaIBiFeRu.cell', 'Synth_12049_BiBiHoLaPdRu-out.cell', 'Synth_12738_PtRuLaLaSnBi.cell', 'Synth_156950_AuRuGdLaSbBi.cell', 'Synth_174471_ErLaSbBiPdRu.cell', 'Synth_83378_CeLaSbBiPdRu.cell', 'Synth_431662_HoLaInBiRhRu.cell', 'Synth_101011_CeLaSnBiCuRu.cell', 'Synth_7781_ErLaSnBiNiRu.cell', 'Synth_150777_PtRuCeLaSnBi.cell', 'Synth_423170_IrRuLaLaSbBi.cell', 'Synth_412576_PtRuDyLaInBi.cell', 'Synth_182050_EuLaSnBiCuRu.cell', 'Synth_173171_YbLaSbBiCdRu.cell', 'Synth_154741_ErLaTeBiCuRu.cell', 'Synth_192462_ErLaSnBiCuRu.cell', 'Synth_13930_LaLaSbBiPdRu.cell', 'Synth_189116_CeLaSnBiPdRu.cell', 'Synth_168470_AuRuErLaTeBi.cell', 'Synth_411077_PrLaInBiNiRu.cell', 'Synth_192802_BiBiTbLaFeRu.cell', 'Synth_8494_PrLaSbBiPdRu.cell', 'Synth_419491_AuRuPrLaSnBi.cell', 'Synth_55495_CeLaSnBiNiRu.cell', 'Synth_101016_LaLaInBiNiRu.cell', 'Synth_150404_PrLaSbBiNiRu.cell', 'Synth_185105_LaLaInBiNiRu.cell', 'Synth_157336_GdLaSbBiCoRu.cell', 'Synth_11406_LaLaIBiRuRu.cell', 'Synth_183028_TmLaSnBiCuRu.cell', 'Synth_65000_CeLaInBiNiRu.cell', 'Synth_190838_CeLaSnBiPdRu.cell', 'Synth_20350_CeLaSnBiNiRu.cell', 'Synth_67988_GdLaIBiMnRu.cell', 'Synth_80005_CeLaSbBiPdRu.cell', 'Synth_5620_GdLaInBiNiRu.cell', 'Synth_412577_PtRuTbLaInBi.cell', 'Synth_62893_PrLaInBiNiRu.cell', 'Synth_420766_YbLaSnBiNiRu.cell', 'Synth_54733_CeLaInBiPdRu.cell', 'Synth_168458_PrLaSbBiFeRu.cell', 'Synth_163719_AuRuCeLaSbBi.cell', 'Synth_55668_NdLaSnBiMnRu.cell', 'Synth_424333_LaLaSnBiRhRu.cell', 'Synth_230729_CeLaSnBiRhRu.cell', 'Synth_183347_LaLaInBiPdRu.cell', 'Synth_12736_PtRuSmLaSnBi.cell', 'Synth_250752_LaLaSnBiZnRu.cell', 'Synth_63511_HoLaSnBiCoRu.cell', 'Synth_12049_BiBiHoLaPdRu.cell', 'Synth_99240_CeLaInBiPdRu.cell', 'Synth_83907_LaLaSbBiCrRu.cell', 'Synth_142736_AuRuCeLaSnBi.cell', 'Synth_244020_AuRuDyLaSbBi.cell', 'Synth_410732_LaLaSnBiRhRu.cell', 'Synth_154791_ErLaTeBiAgRu.cell', 'Synth_55511_SmLaSnBiCoRu.cell', 'Synth_106529_SmLaSnBiCuRu.cell', 'Synth_106417_CeLaSnBiNiRu.cell']
# [{'name': 'Synth_54570_GdLaSnBiCoRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_370040_TbLaInBiCoRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_410419_PtRuYbLaSnBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_67985_PrLaIBiFeRu.cell', 'completion': 'not started', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_12049_BiBiHoLaPdRu-out.cell', 'completion': 'not started', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_12738_PtRuLaLaSnBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_156950_AuRuGdLaSbBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_174471_ErLaSbBiPdRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_83378_CeLaSbBiPdRu.cell', 'completion': 'not started', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_431662_HoLaInBiRhRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_101011_CeLaSnBiCuRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_7781_ErLaSnBiNiRu.cell', 'completion': 'not started', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_150777_PtRuCeLaSnBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_423170_IrRuLaLaSbBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_412576_PtRuDyLaInBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_182050_EuLaSnBiCuRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_173171_YbLaSbBiCdRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_154741_ErLaTeBiCuRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_192462_ErLaSnBiCuRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_13930_LaLaSbBiPdRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_189116_CeLaSnBiPdRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_168470_AuRuErLaTeBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_411077_PrLaInBiNiRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_192802_BiBiTbLaFeRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_8494_PrLaSbBiPdRu.cell', 'completion': 'not started', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_419491_AuRuPrLaSnBi.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_55495_CeLaSnBiNiRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_101016_LaLaInBiNiRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_150404_PrLaSbBiNiRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_185105_LaLaInBiNiRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_157336_GdLaSbBiCoRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_11406_LaLaIBiRuRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_183028_TmLaSnBiCuRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_65000_CeLaInBiNiRu.cell', 'completion': 'not started', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_190838_CeLaSnBiPdRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_20350_CeLaSnBiNiRu.cell', 'completion': 'incomplete', 'error': False, 'error type': 'N/A'}, {'name': 'Synth_67988_GdLaIBiMnRu.cell', 'completion': 'not started', 'error': Fa ...
# [['code', 'structure type', 'permutation', 'completion', 'error', 'error_type'], ['150777', 'Gd3Ni8Sn16', "{'Pt': 'Ru', 'Ce': 'La', 'Sn': 'Bi'}", 'just made', '', ''], ['412576', 'Dy2Pt7In16', "{'Pt': 'Ru', 'Dy': 'La', 'In': 'Bi'}", 'just made', '', ''], ['62893', 'Pr5Ni6In11', "{'Pr': 'La', 'In': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['54733', 'NdRh2Sn4', "{'Ce': 'La', 'In': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['11406', 'Gd2Fe2I', "{'La': 'La', 'I': 'Bi', 'Ru': 'Ru'}", 'just made', '', ''], ['55511', 'La3Al11', "{'Sm': 'La', 'Sn': 'Bi', 'Co': 'Ru'}", 'just made', '', ''], ['411077', 'PrNiIn2', "{'Pr': 'La', 'In': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['101016', 'In6LaNi3', "{'La': 'La', 'In': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['13930', 'Y2Co3Ga9', "{'La': 'La', 'Sb': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['80005', 'Ce3Pd6Sb5', "{'Ce': 'La', 'Sb': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['157336', 'Yb5Sb3', "{'Gd': 'La', 'Sb': 'Bi', 'Co': 'Ru'}", 'just made', '', ''], ['250752', 'La2Zn5Sn', "{'La': 'La', 'Sn': 'Bi', 'Zn': 'Ru'}", 'just made', '', ''], ['150404', 'CeNiSb3(oP60)', "{'Pr': 'La', 'Sb': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['101011', 'Cu6Ce', "{'Ce': 'La', 'Sn': 'Bi', 'Cu': 'Ru'}", 'just made', '', ''], ['424333', 'La16Rh8Sn3', "{'La': 'La', 'Sn': 'Bi', 'Rh': 'Ru'}", 'just made', '', ''], ['370040', 'PrCo2Ga', "{'Tb': 'La', 'In': 'Bi', 'Co': 'Ru'}", 'just made', '', ''], ['423170', 'La2Ir3Sb4', "{'Ir': 'Ru', 'La': 'La', 'Sb': 'Bi'}", 'just made', '', ''], ['173171', '', "{'Yb': 'La', 'Sb': 'Bi', 'Cd': 'Ru'}", 'just made', '', ''], ['106529', 'Cu4Sm2Sn5', "{'Sm': 'La', 'Sn': 'Bi', 'Cu': 'Ru'}", 'just made', '', ''], ['420766', 'Dy7Co4InGe12', "{'Yb': 'La', 'Sn': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['142736', 'La2Zn3Ge6', "{'Au': 'Ru', 'Ce': 'La', 'Sn': 'Bi'}", 'just made', '', ''], ['183347', 'LaPd2In4', "{'La': 'La', 'In': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['12736', 'Zr5Pd9P7', "{'Pt': 'Ru', 'Sm': 'La', 'Sn': 'Bi'}", 'just made', '', ''], ['410419', 'Yb2Pt3Sn5', "{'Pt': 'Ru', 'Yb': 'La', 'Sn': 'Bi'}", 'just made', '', ''], ['7781', 'U3Si2', "{'Er': 'La', 'Sn': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['154741', 'Cu3ErTe3', "{'Er': 'La', 'Te': 'Bi', 'Cu': 'Ru'}", 'just made', '', ''], ['55495', '', "{'Ce': 'La', 'Sn': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['156950', 'Ho5Au2Sb#Mo5SiB2', "{'Au': 'Ru', 'Gd': 'La', 'Sb': 'Bi'}", 'just made', '', ''], ['192462', 'Er3Cu4Sn4', "{'Er': 'La', 'Sn': 'Bi', 'Cu': 'Ru'}", 'just made', '', ''], ['65000', 'Ce4Ni7In8', "{'Ce': 'La', 'In': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['67988', 'Gd3MnI3', "{'Gd': 'La', 'I': 'Bi', 'Mn': 'Ru'}", 'just made', '', ''], ['20350', 'CeNi5Sn', "{'Ce': 'La', 'Sn': 'Bi', 'Ni': 'Ru'}", 'just made', '', ''], ['230729', 'Y2Rh3Sn5', "{'Ce': 'La', 'Sn': 'Bi', 'Rh': 'Ru'}", 'just made', '', ''], ['63511', 'Co6Ho7Sn23', "{'Ho': 'La', 'Sn': 'Bi', 'Co': 'Ru'}", 'just made', '', ''], ['189116', 'Dy2Ni7Sn3', "{'Ce': 'La', 'Sn': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['83378', 'Ce8Pd24Sb', "{'Ce': 'La', 'Sb': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['99240', 'CePd3In2', "{'Ce': 'La', 'In': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['54570', 'Lu3Co8Sn4', "{'Gd': 'La', 'Sn': 'Bi', 'Co': 'Ru'}", 'just made', '', ''], ['12049', 'Heusler(half)#AlLiSi#MgAgAs', "{'Bi': 'Bi', 'Ho': 'La', 'Pd': 'Ru'}", 'just made', '', ''], ['431662', 'Co2In4Lu3', "{'Ho': 'La', 'In': 'Bi', 'Rh': 'Ru'}", 'just made', '', ''], ['183028', 'Ho4Ni2InGe4', "{'Tm': 'La', 'Sn': 'Bi', 'Cu': 'Ru'}", 'just made', '', ''], ['12738', 'Y3Pt4Ge6', "{'Pt': 'Ru', 'La': 'La', 'Sn': 'Bi'}", 'just made', '', ''], ['182050', 'SrCu2Sn2', "{'Eu': 'La', 'Sn': 'Bi', 'Cu': 'Ru'}", 'just made', '', ''], ['83907', 'LaCrSb3', "{'La': 'La', 'Sb': 'Bi', 'Cr': 'Ru'}", 'just made', '', ''], ['174471', 'Sc11Ir4', "{'Er': 'La', 'Sb': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['190838', 'ThTl', "{'Ce': 'La', 'Sn': 'Bi', 'Pd': 'Ru'}", 'just made', '', ''], ['5620' ...
# Synth_code_permutation.cell
# Synth_150777_PtRuCeLaSnBi.cell
# Synth_412576_PtRuDyLaInBi.cell
# Synth_62893_PrLaInBiNiRu.cell
# Synth_54733_CeLaInBiPdRu.cell
# Synth_11406_LaLaIBiRuRu.cell
# Synth_55511_SmLaSnBiCoRu.cell
# Synth_411077_PrLaInBiNiRu.cell
# Synth_101016_LaLaInBiNiRu.cell
# Synth_13930_LaLaSbBiPdRu.cell
# Synth_80005_CeLaSbBiPdRu.cell
# Synth_157336_GdLaSbBiCoRu.cell
# Synth_250752_LaLaSnBiZnRu.cell
# Synth_150404_PrLaSbBiNiRu.cell
# Synth_101011_CeLaSnBiCuRu.cell
# Synth_424333_LaLaSnBiRhRu.cell
# Synth_370040_TbLaInBiCoRu.cell
# Synth_423170_IrRuLaLaSbBi.cell
# Synth_173171_YbLaSbBiCdRu.cell
# Synth_106529_SmLaSnBiCuRu.cell
# Synth_420766_YbLaSnBiNiRu.cell
# Synth_142736_AuRuCeLaSnBi.cell
# Synth_183347_LaLaInBiPdRu.cell
# Synth_12736_PtRuSmLaSnBi.cell
# Synth_410419_PtRuYbLaSnBi.cell
# Synth_7781_ErLaSnBiNiRu.cell
# Synth_154741_ErLaTeBiCuRu.cell
# Synth_55495_CeLaSnBiNiRu.cell
# Synth_156950_AuRuGdLaSbBi.cell
# Synth_192462_ErLaSnBiCuRu.cell
# Synth_65000_CeLaInBiNiRu.cell
# Synth_67988_GdLaIBiMnRu.cell
# Synth_20350_CeLaSnBiNiRu.cell
# Synth_230729_CeLaSnBiRhRu.cell
# Synth_63511_HoLaSnBiCoRu.cell
# Synth_189116_CeLaSnBiPdRu.cell
# Synth_83378_CeLaSbBiPdRu.cell
# Synth_99240_CeLaInBiPdRu.cell
# Synth_54570_GdLaSnBiCoRu.cell
# Synth_12049_BiBiHoLaPdRu.cell
# Synth_431662_HoLaInBiRhRu.cell
# Synth_183028_TmLaSnBiCuRu.cell
# Synth_12738_PtRuLaLaSnBi.cell
# Synth_182050_EuLaSnBiCuRu.cell
# Synth_83907_LaLaSbBiCrRu.cell
# Synth_174471_ErLaSbBiPdRu.cell
# Synth_190838_CeLaSnBiPdRu.cell
# Synth_5620_GdLaInBiNiRu.cell
# Synth_244020_AuRuDyLaSbBi.cell
# Synth_168470_AuRuErLaTeBi.cell
# Synth_192802_BiBiTbLaFeRu.cell
# Synth_8494_PrLaSbBiPdRu.cell
# Synth_419491_AuRuPrLaSnBi.cell
# Synth_185105_LaLaInBiNiRu.cell
# Synth_154791_ErLaTeBiAgRu.cell
# Synth_67985_PrLaIBiFeRu.cell
# Synth_410732_LaLaSnBiRhRu.cell
# Synth_168458_PrLaSbBiFeRu.cell
# Synth_412577_PtRuTbLaInBi.cell
# Synth_163719_AuRuCeLaSbBi.cell
# Synth_106417_CeLaSnBiNiRu.cell
# Synth_55668_NdLaSnBiMnRu.cell
